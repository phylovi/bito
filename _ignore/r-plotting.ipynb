# %%
parameters = t(read.csv("ds7-alpha0.0001-loop1000-eps1e-06-parameters.csv", header=FALSE))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on 'ds7-alpha0.0001-loop1000-eps1e-06-parameters.csv'”

# %%
hist(parameters)
# Out:
# Plot with title “Histogram of parameters”

# %%
sum(parameters==0) / nrow(parameters)
# Out:
# [1] 0.5233317

# %%
sum(parameters==0)
# Out:
# [1] 1043
